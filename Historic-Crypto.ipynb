# %%
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData

# %%
new = HistoricalData('BTC-USD',300,'2015-07-20-00-00').retrieve_data()
new = new.reset_index()
new['time'] = pd.to_datetime(new['time']).dt.date
new.drop('low', inplace=True, axis=1)
new.drop('high', inplace=True, axis=1)
new.drop('open', inplace=True, axis=1)
new.drop('volume', inplace=True, axis=1)
new = new.groupby('time')[['close']].sum()
idx = pd.date_range('3-29-2010', '9-10-2021')
new.index = pd.DatetimeIndex(new.index)
new = new.reindex(idx, fill_value=0)
new['close'] = new['close'].div(288)
new
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 2167 extracted
# Data for chunk 1 of 2167 extracted
# Data for chunk 2 of 2167 extracted
# Data for chunk 3 of 2167 extracted
# Data for chunk 4 of 2167 extracted
# Data for chunk 5 of 2167 extracted
# Data for chunk 6 of 2167 extracted
# Data for chunk 7 of 2167 extracted
# Data for chunk 8 of 2167 extracted
# Data for chunk 9 of 2167 extracted
# Data for chunk 10 of 2167 extracted
# Data for chunk 11 of 2167 extracted
# Data for chunk 12 of 2167 extracted
# Data for chunk 13 of 2167 extracted
# Data for chunk 14 of 2167 extracted
# Data for chunk 15 of 2167 extracted
# Data for chunk 16 of 2167 extracted
# Data for chunk 17 of 2167 extracted
# Data for chunk 18 of 2167 extracted
# ...

# %%
new = new.reset_index()
new.to_csv('BTC_Price.csv', sep=',', index=False)

# %%
new
# Out:
#           index         close
# 0    2010-03-29      0.000000
# 1    2010-03-30      0.000000
# 2    2010-03-31      0.000000
# 3    2010-04-01      0.000000
# 4    2010-04-02      0.000000
# ...         ...           ...
# 4179 2021-09-06  51791.179757
# 4180 2021-09-07  49952.369097
# 4181 2021-09-08  46291.611458
# 4182 2021-09-09  46422.574653
# 4183 2021-09-10  45916.547257
#
# [4184 rows x 2 columns]

# %%
new[3040:3090]
# Out:
#           index        close
# 3040 2018-07-25  8250.845694
# 3041 2018-07-26  8189.174444
# 3042 2018-07-27  8015.515451
# 3043 2018-07-28  8176.635000
# 3044 2018-07-29  8201.659410
# 3045 2018-07-30  8132.552604
# 3046 2018-07-31  7912.548715
# 3047 2018-08-01  7567.695972
# 3048 2018-08-02  7588.741701
# 3049 2018-08-03  7394.514340
# 3050 2018-08-04  7249.691771
# 3051 2018-08-05  6997.377569
# 3052 2018-08-06  6989.845347
# 3053 2018-08-07  6986.721875
# 3054 2018-08-08  6446.123160
# 3055 2018-08-09  6396.429306
# 3056 2018-08-10  2188.155139
# 3057 2018-08-11  6191.735764
# 3058 2018-08-12  6307.606076
# 3059 2018-08-13  6347.200590
# 3060 2018-08-14  6059.041042
# 3061 2018-08-15  6370.819931
# 3062 2018-08-16  6345.614722
# 3063 2018-08-17  6468.885521
# 3064 2018-08-18  6454.271736
# 3065 2018-08-19  6401.562639
# 3066 2018-08-20  6444.791597
# 3067 2018-08-21  6399.582153
# 3068 2018-08-22  6578.289931
# 3069 2018-08-23  6434.320729
# 3070 2018-08-24  6550.973889
# ...
